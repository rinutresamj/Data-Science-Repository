# %% [markdown]
# <a href="https://colab.research.google.com/github/rinutresamj/Data-Science-Repository/blob/main/EDA_with_Time_Series_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA with Time Series Data

# %%
import pandas_datareader as pdr
import pandas as pd

# %%
pip install datetime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 52 kB 655 kB/s
# ...
#      |████████████████████████████████| 251 kB 34.4 MB/s
# ...

# %%
from datetime import datetime

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 962 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import yfinance
df_tesla = yfinance.download (tickers = "TSLA", start = "2017-02-27", 
                              end = "2022-06-17", interval = "1D", group_by = 'ticker', auto_adjust = True, treads = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_tesla
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2017-02-27   16.544666   16.557333   16.134001   16.415333  171912000
# 2017-02-28   16.279333   16.733334   16.260000   16.666000   91171500
# 2017-03-01   16.945333   16.990000   16.607332   16.667999   72142500
# 2017-03-02   16.647333   16.885332   16.551332   16.698668   50277000
# 2017-03-03   16.716000   16.793333   16.600000   16.771334   43791000
# ...                ...         ...         ...         ...        ...
# 2022-06-10  235.156662  239.500000  227.913330  232.229996   97536600
# 2022-06-13  223.166672  226.633331  214.683334  215.736664  102767400
# 2022-06-14  218.286667  226.330002  211.736664  220.889999   97988700
# 2022-06-15  220.916672  235.663330  218.149994  233.000000  119131800
# 2022-06-16  222.736664  225.166672  208.693329  213.100006  107390700
#
# [1337 rows x 5 columns]

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2022-06-10  235.156662  239.500000  227.913330  232.229996   97536600
# 2022-06-13  223.166672  226.633331  214.683334  215.736664  102767400
# 2022-06-14  218.286667  226.330002  211.736664  220.889999   97988700
# 2022-06-15  220.916672  235.663330  218.149994  233.000000  119131800
# 2022-06-16  222.736664  225.166672  208.693329  213.100006  107390700

# %%
#plottng the feature high in dataset
df_tesla['High'].plot(figsize=(12,4))

# %%
#plottng the feature high in dataset with xlimit and ylimit
df_tesla['High'].plot ( xlim=['2020-02-02','2021-08-09'],ylim=[0,900],figsize=(12,4),ls='--',c='green')

# %%
#printing the index
df_tesla.index
# Out:
# DatetimeIndex(['2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10',
#                ...
#                '2022-06-03', '2022-06-06', '2022-06-07', '2022-06-08',
#                '2022-06-09', '2022-06-10', '2022-06-13', '2022-06-14',
#                '2022-06-15', '2022-06-16'],
#               dtype='datetime64[ns]', name='Date', length=1337, freq=None)

# %%
#printing the data within the timeframe 2020-02-02 to 2021-08-09
df_tesla.loc['2020-02-02':'2021-08-09']
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2020-02-03   44.912666   52.409332   44.901333   52.000000  705975000
# 2020-02-04   58.863998   64.599335   55.591999   59.137333  914082000
# 2020-02-05   54.883999   56.398666   46.940666   48.980000  726357000
# 2020-02-06   46.661331   53.055332   45.799999   49.930668  598212000
# 2020-02-07   48.703335   51.316666   48.666668   49.871334  255952500
# ...                ...         ...         ...         ...        ...
# 2021-08-03  239.666672  240.883331  233.669998  236.580002   64860900
# 2021-08-04  237.000000  241.633331  236.309998  236.973328   51007800
# 2021-08-05  238.666672  240.316666  237.136673  238.210007   38758800
# 2021-08-06  237.300003  238.776672  232.543335  233.033340   46869000
# 2021-08-09  236.723328  239.676666  235.043335  237.919998   44145900
#
# [383 rows x 5 columns]

# %%
#extracting the share open price of  data within the timeframe 2020-02-02 to 2021-08-09
share_open=df_tesla.loc['2020-02-02':'2021-08-09']['Open']
share_open
# Out:
# Date
# 2020-02-03     44.912666
# 2020-02-04     58.863998
# 2020-02-05     54.883999
# 2020-02-06     46.661331
# 2020-02-07     48.703335
#                  ...
# 2021-08-03    239.666672
# 2021-08-04    237.000000
# 2021-08-05    238.666672
# 2021-08-06    237.300003
# 2021-08-09    236.723328
# Name: Open, Length: 383, dtype: float64

# %%
#extracting the index of  data within the timeframe 2020-02-02 to 2021-08-09
index=df_tesla.loc['2020-02-02':'2021-08-09'].index
index
# Out:
# DatetimeIndex(['2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#                '2020-02-07', '2020-02-10', '2020-02-11', '2020-02-12',
#                '2020-02-13', '2020-02-14',
#                ...
#                '2021-07-27', '2021-07-28', '2021-07-29', '2021-07-30',
#                '2021-08-02', '2021-08-03', '2021-08-04', '2021-08-05',
#                '2021-08-06', '2021-08-09'],
#               dtype='datetime64[ns]', name='Date', length=383, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots